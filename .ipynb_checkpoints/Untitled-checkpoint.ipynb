# %%
#import necessary pacakges
from skimage.metrics import structural_similarity
import imutils
import cv2
import requests
from PIL import Image

# %%
# Open Image and display
original = Image.open(requests.get('https://www.thestatesman.com/wp-content/uploads/2019/07/pan-card.jpg',stream=True).raw)
tampered = Image.open(requests.get('https://assets1.cleartax-cdn.com/s/img/20170526124335/Pan4.png', stream = True).raw)

# %%
# The file format of the source file. 
print("Original image format: ",original.format)
print("Tampered image format: ",tampered.format)

#Image size, in pixels. The size is given as a 2-tuple (width,height).
print("Original image format: ",original.size)
print("Tampered image format: ",tampered.size)
# Out:
# Original image format:  JPEG
# Tampered image format:  PNG
# Original image format:  (1200, 800)
# Tampered image format:  (282, 179)

# %%
#Resize Image
original = original.resize((250,160))
print(original.size)
original.save('pan_card_tampering/image/original.png')
tampered = tampered.resize((250,160))
print(tampered.size)
tampered.save('pan_card_tampering/image/tampered.png')
# Out:
# (250, 160)
# (250, 160)

# %%
original
# Out:
# <PIL.Image.Image image mode=RGB size=250x160>

# %%
tampered
# Out:
# <PIL.Image.Image image mode=RGBA size=250x160>

# %%
#load the two input images
original = cv2.imread('pan_card_tampering/image/orginal.png')
tampered = cv2.imread('pan_card_tampering/image/tampered.png')

# %%
original_gray = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
tampered_gray = cv2.cvtColor(tampered, cv2.COLOR_BGR2GRAY)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 original_gray = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
#       2 tampered_gray = cv2.cvtColor(tampered, cv2.COLOR_BGR2GRAY)
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
# Compute the Structural similarity Index between the two images.

(score,diff) = structural_similarity(original_gray,tampered_gray, full=True)
diff = (diff + 255).astype("uint8")
print("SSIM: {}".format(score))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 # Compute the Structural similarity Index between the two images.
# ----> 3 (score,diff) = structural_similarity(original_gray,tampered_gray, full=True)
#       4 diff = (diff + 255).astype("uint8")
#       5 print("SSIM: {}".format(score))
#
# NameError: name 'original_gray' is not defined
